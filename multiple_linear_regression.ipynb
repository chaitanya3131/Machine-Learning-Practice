# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r"C:\Users\CHAIT\OneDrive\Desktop\TE\Machine Learning\Dataset\multiple_linear_regression_dataset.csv")
df.head()
df.shape
# Out:
# (40, 3)

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,2]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(x_test)
print("result",y_test)
# Out:
#     Age  Experience
# 19   41          15
# 16   38          12
# 15   37          11
# 26   30           3
# 4    26           2
# 12   34           8
# 37   31           7
# 27   35           6
# result 19    970000
# 16    810000
# 15    760000
# 26    410000
# 4     360000
# 12    630000
# 37    570000
# 27    610000
# Name: Salary, dtype: int64

# %%
lr.predict([[30,3]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([440780.47180766])

# %%
sns.pairplot(data=df)
